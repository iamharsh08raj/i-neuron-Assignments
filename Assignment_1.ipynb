# %% [markdown]
# 1. In the below elements which of them are values or an expression? eg:- values can be integer or string and expressions will be mathematical operators.
# * -- Expression
# 'hello' --Values
# -87.8 --Values
# -  -- Expression
# /  -- Expression
# +	 -- Expression
# 6  -- Values

# %% [markdown]
# 2. What is the difference between string and variable?
# A variable is where we store values and a string is a type of value stored in a variable.
# Eg: x=’Harsh’
# Here x is a variable and ‘Harsh’ is a string.
#
# 3. Describe three different data types.
# Integer- Integer is a data type which stores whole numbers.
# Eg- 1,2,3,etc.
# String- String is a data type that stores sequence of characters.
# Eg- “Harsh”
# Boolean- String is a data type that stores two values True & False.

# %% [markdown]
# 4. What is an expression made up of? What do all expressions do?
# An expression consists of operators and operands that is interpreted to produce some other value. An expression is evaluated as per the precedence of its operators.
#
# 5. This assignment statements, like spam = 10. What is the difference between an expression and a statement?
# An expression is a combination of values and functions that are combined and interpreted by the compiler to create a new value, A statement which is just a standalone unit of execution and doesn't return anything.
#
# 6. After running the following code, what does the variable bacon contain?
# bacon = 22
# bacon + 1
# Output - 23

# %% [markdown]
# 7. What should the values of the following two terms be?
# 'spam' + 'spamspam'
# 'spam' * 3
# The values will be same for the above two statements-
# spamspamspam
#
# 8. Why is eggs a valid variable name while 100 is invalid?
# Because variable name should start with a letter or underscore character.

# %% [markdown]
# 9. What three functions can be used to get the integer, floating-point number, or string version of a value?
# Int() – For Integer
# str() – For String
# float – For Float
# 10. Why does this expression cause an error? How can you fix it?
# 'I have eaten ' + 99 + ' burritos.'
# Because the 99 value becomes the heterogeneous data type in the above exprerssion.
